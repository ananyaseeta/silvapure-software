# %% [markdown]
# # Anomaly Detection Baseline
#
# **Primary dataset:** UCI Water Treatment Plant (unsupervised)
# **Evaluation framework:** NAB (https://github.com/numenta/NAB)
# **See:** `datasets/anomaly-detection/uci-wastewater-anomaly.md`, `datasets/anomaly-detection/nab.md`
# **Purpose:** Phase 1 research — Isolation Forest and LSTM Autoencoder baselines.
#
# **Note on SWaT:**
# This notebook uses UCI WTP and NAB only. SWaT requires a signed data usage agreement with SUTD iTrust.
# See `datasets/anomaly-detection/swat.md` for access instructions.
#
# ## Setup
#
# Download datasets and place at:
# - `data/raw/water-quality/uci-wtp/water-treatment.data`
# - `data/raw/anomaly-detection/nab/` (clone from https://github.com/numenta/NAB)
#
# The `data/` directory is gitignored.

# %%
# Placeholder — implementation in Phase 1
raise NotImplementedError('Implement in Phase 1 research')
