# %% [markdown]
# # NASA CMAPSS — RUL Regression Baseline
#
# **Dataset source:** https://data.nasa.gov/Aerospace/CMAPSS-Jet-Engine-Simulated-Data/ff5v-kuh6
# **License:** US Federal Public Domain (verify current terms)
# **See:** `datasets/predictive-maintenance/nasa-cmapss.md`
# **Purpose:** Phase 1 research — RUL regression methodology for Predictive Maintenance model.
#
# ## Setup
#
# Download CMAPSS and place files at `data/raw/predictive-maintenance/cmapss/`.
#
# The `data/` directory is gitignored. Do not commit dataset files.

# %%
# Placeholder — implementation in Phase 1
raise NotImplementedError('Implement in Phase 1 research')
