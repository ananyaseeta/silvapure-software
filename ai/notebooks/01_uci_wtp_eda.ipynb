# %% [markdown]
# # UCI Water Treatment Plant — Exploratory Data Analysis
#
# This notebook explores the UCI Water Treatment Plant dataset.
#
# **Dataset source:** https://archive.ics.uci.edu/dataset/207/water+treatment+plant
# **See:** `datasets/water-quality/uci-water-treatment-plant.md`
# **Purpose:** Phase 1 research — feature exploration for Water Quality Prediction and Plant Health models.
#
# ## Setup
#
# Download the dataset and place it at `data/raw/water-quality/uci-wtp/water-treatment.data`.
#
# The `data/` directory is gitignored. Do not commit dataset files.

# %%
# Placeholder — implementation in Phase 1
raise NotImplementedError('Implement in Phase 1 research')
